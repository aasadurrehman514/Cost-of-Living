# %%
import pandas as pd

# %%
col = pd.read_csv('costofliving.csv')
col.head()
# Out:
#    Rank                 City  Cost of Living Index  Rent Index
# 0   NaN    Hamilton, Bermuda                149.02       96.10  \
# 1   NaN  Zurich, Switzerland                131.24       69.26
# 2   NaN   Basel, Switzerland                130.93       49.38
# 3   NaN     Zug, Switzerland                128.13       72.12
# 4   NaN  Lugano, Switzerland                123.99       44.99
#
#    Cost of Living Plus Rent Index  Groceries Index  Restaurant Price Index
# 0                          124.22           157.89                  155.22  \
# 1                          102.19           136.14                  132.52
# 2                           92.70           137.07                  130.95
# 3                          101.87           132.61                  130.93
# 4                           86.96           129.17                  119.80
#
#    Local Purchasing Power Index
# 0                         79.43
# 1                        129.79
# 2                        111.53
# ...

# %%
col.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 578 entries, 0 to 577
# Data columns (total 8 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Rank                            0 non-null      float64
#  1   City                            578 non-null    object
#  2   Cost of Living Index            578 non-null    float64
#  3   Rent Index                      578 non-null    float64
#  4   Cost of Living Plus Rent Index  578 non-null    float64
#  5   Groceries Index                 578 non-null    float64
#  6   Restaurant Price Index          578 non-null    float64
#  7   Local Purchasing Power Index    578 non-null    float64
# dtypes: float64(7), object(1)
# memory usage: 36.2+ KB

# %%
col.describe()
# Out:
#        Rank  Cost of Living Index  Rent Index  Cost of Living Plus Rent Index
# count   0.0            578.000000  578.000000                      578.000000  \
# mean    NaN             57.541349   26.650657                       43.061228
# std     NaN             21.656441   17.841544                       18.903751
# min     NaN             18.550000    2.370000                       10.970000
# 25%     NaN             38.015000   12.265000                       26.145000
# 50%     NaN             62.405000   23.280000                       44.990000
# 75%     NaN             73.030000   36.615000                       55.720000
# max     NaN            149.020000  108.420000                      124.220000
#
#        Groceries Index  Restaurant Price Index  Local Purchasing Power Index
# count       578.000000              578.000000                    578.000000
# mean         53.566782               54.354360                     71.504481
# ...

# %%
col.round()
# Out:
#      Rank                  City  Cost of Living Index  Rent Index
# 0     NaN     Hamilton, Bermuda                 149.0        96.0  \
# 1     NaN   Zurich, Switzerland                 131.0        69.0
# 2     NaN    Basel, Switzerland                 131.0        49.0
# 3     NaN      Zug, Switzerland                 128.0        72.0
# 4     NaN   Lugano, Switzerland                 124.0        45.0
# ..    ...                   ...                   ...         ...
# 573   NaN         Kanpur, India                  21.0         4.0
# 574   NaN     Karachi, Pakistan                  21.0         5.0
# 575   NaN  Rawalpindi, Pakistan                  21.0         5.0
# 576   NaN      Multan, Pakistan                  19.0         3.0
# 577   NaN    Peshawar, Pakistan                  19.0         2.0
#
#      Cost of Living Plus Rent Index  Groceries Index  Restaurant Price Index
# 0                             124.0            158.0                   155.0  \
# ...

# %%
print(col.rename)
# Out:
# <bound method DataFrame.rename of      Rank                  City  Cost of Living Index  Rent Index
# 0     NaN     Hamilton, Bermuda                149.02       96.10  \
# 1     NaN   Zurich, Switzerland                131.24       69.26
# 2     NaN    Basel, Switzerland                130.93       49.38
# 3     NaN      Zug, Switzerland                128.13       72.12
# 4     NaN   Lugano, Switzerland                123.99       44.99
# ..    ...                   ...                   ...         ...
# 573   NaN         Kanpur, India                 20.79        3.60
# 574   NaN     Karachi, Pakistan                 20.75        4.84
# 575   NaN  Rawalpindi, Pakistan                 20.52        4.78
# 576   NaN      Multan, Pakistan                 18.68        2.94
# 577   NaN    Peshawar, Pakistan                 18.55        2.37
#
#      Cost of Living Plus Rent Index  Groceries Index  Restaurant Price Index
# ...

# %%
print(col.City.unique())
# Out:
# ['Hamilton, Bermuda' 'Zurich, Switzerland' 'Basel, Switzerland'
#  'Zug, Switzerland' 'Lugano, Switzerland' 'Lausanne, Switzerland'
#  'Beirut, Lebanon' 'Bern, Switzerland' 'Geneva, Switzerland'
#  'Stavanger, Norway' 'Honolulu, HI, United States' 'Oslo, Norway'
#  'Bergen, Norway' 'New York, NY, United States' 'Trondheim, Norway'
#  'Tromso, Norway' 'Reykjavik, Iceland' 'Saint Helier, Jersey'
#  'Santa Barbara, CA, United States' 'Tel Aviv-Yafo, Israel'
#  'Berkeley, CA, United States' 'San Francisco, CA, United States'
#  'Oakland, CA, United States' 'Anchorage, AK, United States'
#  'Santa Clara, CA, United States' 'Petah Tikva, Israel'
#  'Beersheba, Israel' 'Seattle, WA, United States' 'Copenhagen, Denmark'
#  'Arhus, Denmark' 'Haifa, Israel' 'Jerusalem, Israel' 'Nassau, Bahamas'
#  'London, United Kingdom' 'Tokyo, Japan' 'Boston, MA, United States'
#  'Nice, France' 'Paris, France' 'Queens, NY, United States'
#  'Singapore, Singapore' 'Washington, DC, United States'
# ...

# %%
import matplotlib.pyplot as plt
plt.scatter(col['Rent Index'],col['Cost of Living Plus Rent Index'])

# %%
import seaborn as sns
sns.lineplot(x='Rent Index',y='Groceries Index',data=col)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[51], line 2
#       1 import seaborn as sns
# ----> 2 sns.lineplot(x='Rent Index',y='Groceries Index',data=col)
#
# File ~/.local/lib/python3.10/site-packages/seaborn/relational.py:645, in lineplot(data, x, y, hue, size, style, units, palette, hue_order, hue_norm, sizes, size_order, size_norm, dashes, markers, style_order, estimator, errorbar, n_boot, seed, orient, sort, err_style, err_kws, legend, ci, ax, **kwargs)
#     642 color = kwargs.pop("color", kwargs.pop("c", None))
#     643 kwargs["color"] = _default_color(ax.plot, hue, color, kwargs)
# --> 645 p.plot(ax, kwargs)
#     646 return ax
#
# File ~/.local/lib/python3.10/site-packages/seaborn/relational.py:459, in _LinePlotter.plot(self, ax, kws)
#     457         lines.extend(ax.plot(unit_data["x"], unit_data["y"], **kws))
#     458 else:
# ...
